# %% [markdown]
# LLM CALL

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv(dotenv_path="../.env")

client=OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
chat_completion=client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role":"system","content":"You are a helpful assistant."},
        {"role":"user","content":"What is the capital of France?"}
    ]
)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[7], line 7
#       3 from openai import OpenAI
#       4
#       5 load_dotenv(dotenv_path="../.env")
#       6
# ----> 7 client=OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
#       8 chat_completion=client.chat.completions.create(
#       9     model="gpt-3.5-turbo",
#      10     messages=[
#
# File e:\langchain_tutorial\.venv\Lib\site-packages\openai\_client.py:158, in OpenAI.__init__(self, api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     156     api_key = os.environ.get("OPENAI_API_KEY")
#     157 if api_key is None:
# --> 158     raise OpenAIError(
#     159         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     160     )
#     161 if callable(api_key):
#     162     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

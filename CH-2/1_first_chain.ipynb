# %% [markdown]
# # **Chains

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

load_dotenv(dotenv_path="../.env")

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI_API KEY is set")
else:
    raise ValueError("OPENAI_API_KEY is not set in environment variables")

from langchain_openai import ChatOpenAI
from langchain_core.prompts import  ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm_openai = ChatOpenAI(model="gpt-5-mini", temperature=0.9, max_tokens=1000)
llm_openai.invoke("What is the temperature today in Minnesota Minnetonka?").content
# Out:
# OPENAI_API KEY is set
# 'I can’t fetch real‑time data from here. If you want the current temperature in Minnetonka, MN right now, you can:\n\n- Open your phone’s Weather app or Google and search “Minnetonka MN weather”.\n- Use a quick web lookup like weather.com or the NWS forecast for Minnetonka.\n\nIf you want to fetch it yourself from the command line or a script, here are two quick options:\n\n- wttr.in (no API key):\n  - URL: https://wttr.in/Minnetonka?format=3\n  - Example (curl): curl https://wttr.in/Minnetonka?format=3\n\n- Open‑Meteo (no key; returns JSON with current temperature). Minnetonka coordinates ~44.9216, -93.4680:\n  - URL: https://api.open-meteo.com/v1/forecast?latitude=44.9216&longitude=-93.4680&current_weather=true&temperature_unit=fahrenheit\n\nTell me if you’d like me to show how to use one of these, or if you prefer the current temperature and can allow me to look it up another way.'

# %% [markdown]
# First Chain

# %%
#Task -1 

prompt_template = ChatPromptTemplate.from_messages(
    [("system","You are a helpful assistant that provides weather information"),
     ("human","{input}")])

print(prompt_template)
# Out:
# input_variables=['input'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant that provides weather information'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]

# %%
#Task -2

llm_openai = ChatOpenAI(model="gpt-5-mini", temperature=0.9, max_tokens=1000)

# %%
#Task -3

str_parser=StrOutputParser()

# %% [markdown]
# Manual Invocation

# %%
template=prompt_template.invoke(input="What is the capital of France?")
response=llm_openai.invoke(template)
response.content
# Out:
# 'The capital of France is Paris.'

# %% [markdown]
# Chain Invocation

# %%
chain = prompt_template | llm_openai | str_parser
chain.invoke(input="What is the capital of France?")
# Out:
# 'The capital of France is Paris.'

# %%
from langchain_core.runnables import RunnableSequence

chain_1=RunnableSequence(prompt_template,llm_openai,str_parser)
chain_1.invoke(input="What is the capital of France?")
# Out:
# 'The capital of France is Paris.'
